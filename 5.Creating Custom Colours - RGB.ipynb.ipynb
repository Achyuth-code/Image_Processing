# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Creating different Colours

# %%
arr = np.array([[[ 249  , 220 , 104 ] ,  [ 55  , 126 , 34 ] ,[ 90  , 0 , 0 ]],
                 [[ 139  , 206 , 247 ] , [ 239 , 134 , 59 ] ,[ 180 , 0 , 0 ]],
                 [[ 113  , 178 , 229 ] , [ 240 , 0 , 0 ] ,   [ 255 , 0 , 0 ]]])
plt.imshow(arr)

# %% [markdown]
# # creating orange colour

# %%
img = []

for i in range(739):
    t = []
    for j in range(1080):
        t.append([239,134,59])
    img.append(t)

plt.imshow(img)

# %%
img = []

for i in range(739):
    t = []
    for j in range(1080):
        t.append([59, 134, 239])
    img.append(t)

plt.imshow(img)
